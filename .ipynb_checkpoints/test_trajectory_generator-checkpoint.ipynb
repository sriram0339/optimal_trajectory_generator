# %% [markdown]
# # Test the trajectory generation functionality

# %%
using DifferentialEquations
using Plots

# %%
include("trajectory_optimization.jl")
# Out:
# optimize_trajectory (generic function with 2 methods)

# %%
dyn_sys = DynamicalSystem(vehicle_model, [2.0], [0., 0. , 0. , 3.0])
ctrls = 0.5 * randn(50, 2)
# Out:
# 50×2 Matrix{Float64}:
#   0.882719   -0.0610134
#   0.489689    0.153563
#   0.162435    0.30166
#   0.29478     0.189194
#   0.309632   -0.0518526
#   0.644505    0.850308
#  -0.420261    0.28249
#  -0.61919     0.470082
#  -0.580138    0.0758496
#  -0.169659    0.336631
#   ⋮
#   0.0263182   0.0534812
#  -0.951307   -0.534398
#  -0.0932701   0.683655
#   0.768273    0.335365
#   0.76623     0.970684
#   1.05728     0.037703
#   0.478244    0.639296
#   0.647693    0.212055
#  -0.328245   -0.775273

# %%
(X, T) = generate_trajectory(dyn_sys,  ctrls, 0.1 )
print(size(X))
# Out:
# (250, 4)

# %%
# create a plot with two subplots 

p1 = plot(X[:, 1], X[:, 2], label="Trajectory",  xlabel="x", ylabel="y")
p2 = plot(T, X[:,4],label="Velocity", xlabel="Time", ylabel="Velocity", label_location=:topright)
p3 = plot(T, X[:,3],label="Heading", xlabel="Time", ylabel="Heading", label_location=:topright)
plot(p1, p2, p3, layout=(3,1))

# %%
obstacle_locations = [
    [2.0, 1.0], 
    [6.0, 2.5],
    [10.0, 5.0]
]
waypoints =[ [i*0.5, i*0.25] for i in 0:25]

target_velocity = 2.5
winfo = Workspace(obstacle_locations, waypoints, target_velocity)

(X, U, T) = optimize_trajectory(winfo, dyn_sys, 0.25, [(-1.0, 1.0), (-0.5, 0.5)], ; weights=[1.0, 1.0, 0.1, 0.1, 2.0])

# %%
print(size(X))
plot(X[:, 1], X[:, 2], label="Trajectory",  xlabel="x", ylabel="y")
plot!([waypoints[i][1] for i in 1:length(waypoints)], [waypoints[i][2] for i in 1:length(waypoints)], marker=:cross, label="Waypoints", xlabel="x", ylabel="y", linestyle=:dash)
# plot each obstacle as a circle of radius 0.5
for obs in obstacle_locations
    plot!([obs[1]], [obs[2]], marker=:circle, label="Obstacle", xlabel="x", ylabel="y", linestyle=:dash, markersize=10)
end
plot!()
#p2 = plot(T, X[:,4],label="Velocity", xlabel="Time", ylabel="Velocity", label_location=:topright)
#p3 = plot(T, X[:,3],label="Heading", xlabel="Time", ylabel="Heading", label_location=:topright)
#plot(p1, p2, p3, layout=(3,1))
